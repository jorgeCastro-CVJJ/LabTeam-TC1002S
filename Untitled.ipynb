# %% [markdown]
# # Obtención de Estadísticas Descriptivas
#
# El siguiente codigo tiene como propósito poder leer los datos del archivo **student-math.csv** donde podemos encontrar
# información acerca de el consumo de alcohol en estudiantes de un curso de matemáticas.
#
# Buscamos lo siguiente:
# 1. _Saber el consumo promedio de los estudiantes_
# 2. _¿Hay correlación entre calificaciones-consumo?_
# 3. _¿Cómo afecta la salud respecto al consumo de alcohol?_
# 4. _Entender el comportamiento de los estudiantes según su edad y rendimiento académico (tomando en cuenta ausencias)_
#
#
# La librería que se estará usando es pandas; sin embargo, se hizo uso de python para visualizar los datos en primera instancia.

# %%
import csv
with open ('../LabTeam/student-mat.csv') as csvFile:
    reader = csv.reader(csvFile, delimiter = ",")
    for row in reader:
        print(row)
# Out:
# ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
# ['GP', 'F', '18', 'U', 'GT3', 'A', '4', '4', 'at_home', 'teacher', 'course', 'mother', '2', '2', '0', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no', '4', '3', '4', '1', '1', '3', '6', '5', '6', '6']
# ['GP', 'F', '17', 'U', 'GT3', 'T', '1', '1', 'at_home', 'other', 'course', 'father', '1', '2', '0', 'no', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'no', '5', '3', '3', '1', '1', '3', '4', '5', '5', '6']
# ['GP', 'F', '15', 'U', 'LE3', 'T', '1', '1', 'at_home', 'other', 'other', 'mother', '1', '2', '3', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'no', '4', '3', '2', '2', '3', '3', '10', '7', '8', '10']
# ...

# %% [markdown]
# # Creación de tabla
#
# Pandas es una de las herramientas que nos permiten visualizar datos separados por comas (csv) de manera más eficaz a comparación del lenguaje pyhton puro. En este caso tomamos como referencia 7 columnas de las 33 columnas disponibles en nuestra base de datos seleccionada debido a que para nuestro propósito no tienen mayor impacto o relevancia.

# %%
import pandas as pd
df = pd.read_csv('../LabTeam/student-mat.csv')
tabla=df[['sex','age','Dalc','Walc','absences','G1','G2','G3']]
tabla.describe()
tabla
# Out:
#     sex  age  Dalc  Walc  absences  G1  G2  G3
# 0     F   18     1     1         6   5   6   6
# 1     F   17     1     1         4   5   5   6
# 2     F   15     2     3        10   7   8  10
# 3     F   15     1     1         2  15  14  15
# 4     F   16     1     2         4   6  10  10
# ..   ..  ...   ...   ...       ...  ..  ..  ..
# 390   M   20     4     5        11   9   9   9
# 391   M   17     3     4         3  14  16  16
# 392   M   21     3     3         3  10   8   7
# 393   M   18     3     4         0  11  12  10
# 394   M   19     3     3         5   8   9   9
#
# [395 rows x 8 columns]

# %%
tabla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sex       395 non-null    object
#  1   age       395 non-null    int64
#  2   Dalc      395 non-null    int64
#  3   Walc      395 non-null    int64
#  4   absences  395 non-null    int64
#  5   G1        395 non-null    int64
#  6   G2        395 non-null    int64
#  7   G3        395 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 24.8+ KB

# %%
import matplotlib.pyplot as plt

tabla1 = df[['age','Dalc','Walc','absences','G1','G2','G3']]

plt.figure();
tabla1.diff().hist(figsize=(10,10),color="b", alpha=0.5)
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'Dalc'}>,
#         <AxesSubplot:title={'center':'Walc'}>],
#        [<AxesSubplot:title={'center':'absences'}>,
#         <AxesSubplot:title={'center':'G1'}>,
#         <AxesSubplot:title={'center':'G2'}>],
#        [<AxesSubplot:title={'center':'G3'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
tabla.min()
# Out:
# sex          F
# age         15
# Dalc         1
# Walc         1
# absences     0
# G1           3
# G2           0
# G3           0
# dtype: object

# %%
tabla.max()
# Out:
# sex          M
# age         22
# Dalc         5
# Walc         5
# absences    75
# G1          19
# G2          19
# G3          20
# dtype: object

# %%
tabla.var()
# Out:
# age          1.628285
# Dalc         0.793420
# Walc         1.658678
# absences    64.049541
# G1          11.017053
# G2          14.148917
# G3          20.989616
# dtype: float64

# %%
tabla.mean()
# Out:
# age         16.696203
# Dalc         1.481013
# Walc         2.291139
# absences     5.708861
# G1          10.908861
# G2          10.713924
# G3          10.415190
# dtype: float64

# %%
tabla.std()
# Out:
# age         1.276043
# Dalc        0.890741
# Walc        1.287897
# absences    8.003096
# G1          3.319195
# G2          3.761505
# G3          4.581443
# dtype: float64
